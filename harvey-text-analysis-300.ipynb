# %%
import pandas as pd
import numpy as np
import re
import joblib

from nltk.tokenize import RegexpTokenizer
from nltk import word_tokenize  
from nltk.stem import WordNetLemmatizer
import warnings

# Sklearn
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.cluster import KMeans

# Plotting tools
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# borrowed from stackoverflow https://stackoverflow.com/a/49146722
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r' ', string)

def remove_unwanted(document):

    # remove URLS 
    document = re.sub(r'http\S+', ' ', document)
    # remove emoji's
    document = remove_emoji(document)
    # remove punctuation
    document = re.sub("[^0-9A-Za-z ]", "" , document)
    # remove double spaces
    document = document.replace('  ',"")
    
    return document.strip()

# %%
# print(data[["Likes","Retweets"]].describe())
# extracted_data = data[(data["Likes"] >= 3) & (data["Retweets"] >= 2)]
# text_corpus = extracted_data["Tweet"]

# %%
data = pd.read_csv("/kaggle/input/harvey-stressor/Harvey_Tweets_with_emotion.csv")

exclusive_emotion = ["approval","desire","admiration","love","gratitude","excitement","optimism","joy","amusement","neutral"]
extracted_data = data.loc[~data["Emotion"].isin(exclusive_emotion)]
text_corpus = extracted_data["Tweet"]

# %%
new_corpus = []

for text in text_corpus:

    clean_text = remove_unwanted(str(text))
    clean_text = ' '.join( [w for w in clean_text.split() if len(w)>1] )
    new_corpus.append(clean_text)

new_corpus = np.array(new_corpus)

# %%
tokenizer = RegexpTokenizer(r'\w+')

tfidf = TfidfVectorizer(lowercase=True,
                        stop_words='english',
                        ngram_range = (1,1),
                        tokenizer = tokenizer.tokenize,
                        max_features=  300,
                        encoding='utf-8')

train_data = tfidf.fit_transform(new_corpus.astype('U'))

# %%
# Materialize the sparse data
data_dense = train_data.todense()

# Compute Sparsicity = Percentage of Non-Zero cells
print("Sparsicity: ", ((data_dense > 0).sum()/data_dense.size)*100, "%")
# Out:
# Sparsicity:  1.6616613559471576 %

# %% [markdown]
# ## SAMPLE LDA

# %%
warnings.filterwarnings('ignore')
lda_model = LatentDirichletAllocation(n_components=20,               # Number of topics
                                      max_iter=10,               # Max learning iterations  
                                      random_state=100,          # Random state
                                      evaluate_every = -1,       # compute perplexity every n iters, default: Don't
                                      n_jobs = -1,               # Use all available CPUs
                                     )
lda_output = lda_model.fit_transform(train_data)

print(lda_model)  # Model attributes
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# LatentDirichletAllocation(n_components=20, n_jobs=-1, random_state=100)

# %%
# Log Likelyhood: Higher the better
print("Log Likelihood: ", lda_model.score(train_data))

# Perplexity: Lower the better. Perplexity = exp(-1. * log-likelihood per word)
print("Perplexity: ", lda_model.perplexity(train_data))

# See model parameters
print(lda_model.get_params())
# Out:
# Log Likelihood:  -1176913.7680234918
# Perplexity:  433.94529671733085
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 20, 'n_jobs': -1, 'perp_tol': 0.1, 'random_state': 100, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}

# %% [markdown]
# ## GridSearch LDA

# %%
# Define Search Param
search_params = {'n_components': [5,6,7,8,9,10], 'learning_decay': [.5,.6,.7,.8,.9]}
# search_params = {'n_components': [10, 15], 'learning_decay': [.5, .7, .9]}

# Init the Model
lda = LatentDirichletAllocation(n_jobs=-1)

# Init Grid Search Class
model = GridSearchCV(lda, param_grid=search_params, verbose=3, cv=5)

# Do the Grid Search
model.fit(train_data)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5] END learning_decay=0.5, n_components=5;, score=-215697.564 total time=  46.5s
# [CV 2/5] END learning_decay=0.5, n_components=5;, score=-218116.538 total time=  48.5s
# [CV 3/5] END learning_decay=0.5, n_components=5;, score=-217300.824 total time=  47.1s
# [CV 4/5] END learning_decay=0.5, n_components=5;, score=-224461.699 total time=  48.8s
# [CV 5/5] END learning_decay=0.5, n_components=5;, score=-217716.180 total time=  49.4s
# [CV 1/5] END learning_decay=0.5, n_components=6;, score=-220633.464 total time=  45.6s
# [CV 2/5] END learning_decay=0.5, n_components=6;, score=-220135.057 total time=  46.5s
# [CV 3/5] END learning_decay=0.5, n_components=6;, score=-220962.212 total time=  46.7s
# [CV 4/5] END learning_decay=0.5, n_components=6;, score=-224811.099 total time=  45.3s
# [CV 5/5] END learning_decay=0.5, n_components=6;, score=-220223.551 total time=  45.8s
# [CV 1/5] END learning_decay=0.5, n_components=7;, score=-222431.074 total time=  44.3s
# [CV 2/5] END learning_decay=0.5, n_components=7;, score=-223634.954 total time=  44.5s
# [CV 3/5] END learning_decay=0.5, n_components=7;, score=-221860.745 total time=  43.6s
# [CV 4/5] END learning_decay=0.5, n_components=7;, score=-227692.379 total time=  45.2s
# [CV 5/5] END learning_decay=0.5, n_components=7;, score=-223245.764 total time=  45.5s
# [CV 1/5] END learning_decay=0.5, n_components=8;, score=-225184.155 total time=  41.9s
# [CV 2/5] END learning_decay=0.5, n_components=8;, score=-227150.781 total time=  42.8s
# [CV 3/5] END learning_decay=0.5, n_components=8;, score=-226840.841 total time=  43.8s
# [CV 4/5] END learning_decay=0.5, n_components=8;, score=-229441.406 total time=  42.0s
# [CV 5/5] END learning_decay=0.5, n_components=8;, score=-226318.407 total time=  43.2s
# [CV 1/5] END learning_decay=0.5, n_components=9;, score=-228919.017 total time=  43.2s
# [CV 2/5] END learning_decay=0.5, n_components=9;, score=-228710.680 total time=  42.4s
# [CV 3/5] END learning_decay=0.5, n_components=9;, score=-227348.873 total time=  42.9s
# [CV 4/5] END learning_decay=0.5, n_components=9;, score=-232202.758 total time=  43.2s
# [CV 5/5] END learning_decay=0.5, n_components=9;, score=-228388.413 total time=  42.6s
# [CV 1/5] END learning_decay=0.5, n_components=10;, score=-229578.199 total time=  42.0s
# [CV 2/5] END learning_decay=0.5, n_components=10;, score=-232171.455 total time=  42.1s
# [CV 3/5] END learning_decay=0.5, n_components=10;, score=-228769.068 total time=  41.5s
# [CV 4/5] END learning_decay=0.5, n_components=10;, score=-233836.461 total time=  41.3s
# [CV 5/5] END learning_decay=0.5, n_components=10;, score=-229587.136 total time=  41.8s
# [CV 1/5] END learning_decay=0.6, n_components=5;, score=-217620.691 total time=  48.1s
# [CV 2/5] END learning_decay=0.6, n_components=5;, score=-216808.372 total time=  46.9s
# [CV 3/5] END learning_decay=0.6, n_components=5;, score=-217573.789 total time=  48.1s
# [CV 4/5] END learning_decay=0.6, n_components=5;, score=-223798.400 total time=  48.8s
# [CV 5/5] END learning_decay=0.6, n_components=5;, score=-217510.391 total time=  48.8s
# [CV 1/5] END learning_decay=0.6, n_components=6;, score=-220458.076 total time=  45.4s
# [CV 2/5] END learning_decay=0.6, n_components=6;, score=-222576.586 total time=  46.5s
# [CV 3/5] END learning_decay=0.6, n_components=6;, score=-221859.581 total time=  46.4s
# [CV 4/5] END learning_decay=0.6, n_components=6;, score=-223383.726 total time=  44.4s
# [CV 5/5] END learning_decay=0.6, n_components=6;, score=-222899.694 total time=  46.4s
# [CV 1/5] END learning_decay=0.6, n_components=7;, score=-223291.592 total time=  44.3s
# [CV 2/5] END learning_decay=0.6, n_components=7;, score=-224146.199 total time=  43.0s
# [CV 3/5] END learning_decay=0.6, n_components=7;, score=-222159.991 total time=  43.9s
# [CV 4/5] END learning_decay=0.6, n_components=7;, score=-227989.355 total time=  44.8s
# [CV 5/5] END learning_decay=0.6, n_components=7;, score=-224847.058 total time=  44.8s
# [CV 1/5] END learning_decay=0.6, n_components=8;, score=-225181.154 total time=  43.1s
# [CV 2/5] END learning_decay=0.6, n_components=8;, score=-225984.128 total time=  43.4s
# [CV 3/5] END learning_decay=0.6, n_components=8;, score=-224763.776 total time=  43.9s
# [CV 4/5] END learning_decay=0.6, n_components=8;, score=-230852.565 total time=  44.7s
# [CV 5/5] END learning_decay=0.6, n_components=8;, score=-226466.095 total time=  44.8s
# [CV 1/5] END learning_decay=0.6, n_components=9;, score=-228466.573 total time=  43.6s
# [CV 2/5] END learning_decay=0.6, n_components=9;, score=-226755.273 total time=  43.3s
# [CV 3/5] END learning_decay=0.6, n_components=9;, score=-227023.163 total time=  43.8s
# [CV 4/5] END learning_decay=0.6, n_components=9;, score=-231449.305 total time=  44.0s
# [CV 5/5] END learning_decay=0.6, n_components=9;, score=-228701.028 total time=  45.0s
# [CV 1/5] END learning_decay=0.6, n_components=10;, score=-229808.713 total time=  43.4s
# [CV 2/5] END learning_decay=0.6, n_components=10;, score=-230782.638 total time=  42.9s
# [CV 3/5] END learning_decay=0.6, n_components=10;, score=-228758.499 total time=  42.9s
# [CV 4/5] END learning_decay=0.6, n_components=10;, score=-232949.057 total time=  43.0s
# [CV 5/5] END learning_decay=0.6, n_components=10;, score=-228798.872 total time=  44.1s
# [CV 1/5] END learning_decay=0.7, n_components=5;, score=-218062.942 total time=  50.1s
# [CV 2/5] END learning_decay=0.7, n_components=5;, score=-220162.987 total time=  50.7s
# [CV 3/5] END learning_decay=0.7, n_components=5;, score=-217578.001 total time=  48.6s
# [CV 4/5] END learning_decay=0.7, n_components=5;, score=-222739.051 total time=  49.7s
# [CV 5/5] END learning_decay=0.7, n_components=5;, score=-219804.066 total time=  49.7s
# [CV 1/5] END learning_decay=0.7, n_components=6;, score=-221424.590 total time=  48.2s
# [CV 2/5] END learning_decay=0.7, n_components=6;, score=-222143.147 total time=  47.3s
# [CV 3/5] END learning_decay=0.7, n_components=6;, score=-219976.305 total time=  48.2s
# [CV 4/5] END learning_decay=0.7, n_components=6;, score=-227969.684 total time=  47.4s
# [CV 5/5] END learning_decay=0.7, n_components=6;, score=-221324.029 total time=  48.6s
# [CV 1/5] END learning_decay=0.7, n_components=7;, score=-222219.331 total time=  45.3s
# [CV 2/5] END learning_decay=0.7, n_components=7;, score=-224004.011 total time=  45.3s
# [CV 3/5] END learning_decay=0.7, n_components=7;, score=-221884.247 total time=  45.6s
# [CV 4/5] END learning_decay=0.7, n_components=7;, score=-226891.299 total time=  45.8s
# [CV 5/5] END learning_decay=0.7, n_components=7;, score=-225278.798 total time=  46.9s
# [CV 1/5] END learning_decay=0.7, n_components=8;, score=-226290.900 total time=  45.7s
# [CV 2/5] END learning_decay=0.7, n_components=8;, score=-225318.411 total time=  43.8s
# [CV 3/5] END learning_decay=0.7, n_components=8;, score=-223978.329 total time=  44.3s
# [CV 4/5] END learning_decay=0.7, n_components=8;, score=-229598.734 total time=  44.0s
# [CV 5/5] END learning_decay=0.7, n_components=8;, score=-225432.959 total time=  44.1s
# [CV 1/5] END learning_decay=0.7, n_components=9;, score=-226884.464 total time=  43.2s
# [CV 2/5] END learning_decay=0.7, n_components=9;, score=-229271.893 total time=  43.5s
# [CV 3/5] END learning_decay=0.7, n_components=9;, score=-226467.309 total time=  43.2s
# [CV 4/5] END learning_decay=0.7, n_components=9;, score=-231720.519 total time=  44.3s
# [CV 5/5] END learning_decay=0.7, n_components=9;, score=-228076.872 total time=  44.6s
# [CV 1/5] END learning_decay=0.7, n_components=10;, score=-229115.859 total time=  42.9s
# [CV 2/5] END learning_decay=0.7, n_components=10;, score=-231096.566 total time=  41.9s
# [CV 3/5] END learning_decay=0.7, n_components=10;, score=-229349.125 total time=  43.6s
# [CV 4/5] END learning_decay=0.7, n_components=10;, score=-233445.588 total time=  42.8s
# [CV 5/5] END learning_decay=0.7, n_components=10;, score=-230016.800 total time=  44.1s
# [CV 1/5] END learning_decay=0.8, n_components=5;, score=-218260.266 total time=  50.5s
# [CV 2/5] END learning_decay=0.8, n_components=5;, score=-217053.567 total time=  48.2s
# [CV 3/5] END learning_decay=0.8, n_components=5;, score=-217316.226 total time=  49.0s
# [CV 4/5] END learning_decay=0.8, n_components=5;, score=-222399.083 total time=  49.7s
# [CV 5/5] END learning_decay=0.8, n_components=5;, score=-219262.316 total time=  49.8s
# [CV 1/5] END learning_decay=0.8, n_components=6;, score=-220046.585 total time=  46.8s
# [CV 2/5] END learning_decay=0.8, n_components=6;, score=-220164.497 total time=  46.2s
# [CV 3/5] END learning_decay=0.8, n_components=6;, score=-221117.195 total time=  46.8s
# [CV 4/5] END learning_decay=0.8, n_components=6;, score=-225055.528 total time=  47.0s
# [CV 5/5] END learning_decay=0.8, n_components=6;, score=-222152.144 total time=  48.6s
# [CV 1/5] END learning_decay=0.8, n_components=7;, score=-223248.700 total time=  45.4s
# [CV 2/5] END learning_decay=0.8, n_components=7;, score=-223299.546 total time=  45.0s
# [CV 3/5] END learning_decay=0.8, n_components=7;, score=-221495.091 total time=  44.7s
# [CV 4/5] END learning_decay=0.8, n_components=7;, score=-227703.658 total time=  46.5s
# [CV 5/5] END learning_decay=0.8, n_components=7;, score=-224424.309 total time=  47.3s
# [CV 1/5] END learning_decay=0.8, n_components=8;, score=-225111.572 total time=  44.9s
# [CV 2/5] END learning_decay=0.8, n_components=8;, score=-227075.328 total time=  44.4s
# [CV 3/5] END learning_decay=0.8, n_components=8;, score=-226477.947 total time=  44.5s
# [CV 4/5] END learning_decay=0.8, n_components=8;, score=-229511.377 total time=  44.6s
# [CV 5/5] END learning_decay=0.8, n_components=8;, score=-225757.010 total time=  46.0s
# [CV 1/5] END learning_decay=0.8, n_components=9;, score=-226904.746 total time=  46.6s
# [CV 2/5] END learning_decay=0.8, n_components=9;, score=-229474.760 total time=  45.5s
# [CV 3/5] END learning_decay=0.8, n_components=9;, score=-229011.880 total time=  46.3s
# [CV 4/5] END learning_decay=0.8, n_components=9;, score=-233804.508 total time=  45.4s
# [CV 5/5] END learning_decay=0.8, n_components=9;, score=-227008.329 total time=  45.0s
# [CV 1/5] END learning_decay=0.8, n_components=10;, score=-229646.243 total time=  43.5s
# [CV 2/5] END learning_decay=0.8, n_components=10;, score=-230141.801 total time=  42.7s
# [CV 3/5] END learning_decay=0.8, n_components=10;, score=-230339.493 total time=  43.5s
# [CV 4/5] END learning_decay=0.8, n_components=10;, score=-232038.133 total time=  44.0s
# [CV 5/5] END learning_decay=0.8, n_components=10;, score=-230729.817 total time=  44.4s
# [CV 1/5] END learning_decay=0.9, n_components=5;, score=-218078.485 total time=  51.2s
# [CV 2/5] END learning_decay=0.9, n_components=5;, score=-216177.140 total time=  48.8s
# [CV 3/5] END learning_decay=0.9, n_components=5;, score=-217267.663 total time=  49.8s
# [CV 4/5] END learning_decay=0.9, n_components=5;, score=-223692.626 total time=  50.8s
# [CV 5/5] END learning_decay=0.9, n_components=5;, score=-217468.908 total time=  49.9s
# [CV 1/5] END learning_decay=0.9, n_components=6;, score=-221271.205 total time=  49.0s
# [CV 2/5] END learning_decay=0.9, n_components=6;, score=-222278.278 total time=  48.6s
# [CV 3/5] END learning_decay=0.9, n_components=6;, score=-220073.218 total time=  47.9s
# [CV 4/5] END learning_decay=0.9, n_components=6;, score=-225385.020 total time=  47.7s
# [CV 5/5] END learning_decay=0.9, n_components=6;, score=-221544.501 total time=  48.8s
# [CV 1/5] END learning_decay=0.9, n_components=7;, score=-223371.134 total time=  46.5s
# [CV 2/5] END learning_decay=0.9, n_components=7;, score=-224983.512 total time=  46.4s
# [CV 3/5] END learning_decay=0.9, n_components=7;, score=-224287.619 total time=  47.4s
# [CV 4/5] END learning_decay=0.9, n_components=7;, score=-226638.355 total time=  46.8s
# [CV 5/5] END learning_decay=0.9, n_components=7;, score=-224436.728 total time=  48.2s
# [CV 1/5] END learning_decay=0.9, n_components=8;, score=-226233.274 total time=  45.6s
# [CV 2/5] END learning_decay=0.9, n_components=8;, score=-226382.953 total time=  45.1s
# [CV 3/5] END learning_decay=0.9, n_components=8;, score=-224931.256 total time=  44.7s
# [CV 4/5] END learning_decay=0.9, n_components=8;, score=-230001.179 total time=  45.5s
# [CV 5/5] END learning_decay=0.9, n_components=8;, score=-225041.096 total time=  46.6s
# [CV 1/5] END learning_decay=0.9, n_components=9;, score=-227402.269 total time=  44.5s
# [CV 2/5] END learning_decay=0.9, n_components=9;, score=-228431.058 total time=  44.4s
# [CV 3/5] END learning_decay=0.9, n_components=9;, score=-227932.060 total time=  44.6s
# [CV 4/5] END learning_decay=0.9, n_components=9;, score=-230886.616 total time=  44.7s
# [CV 5/5] END learning_decay=0.9, n_components=9;, score=-229290.049 total time=  45.6s
# [CV 1/5] END learning_decay=0.9, n_components=10;, score=-229371.038 total time=  44.2s
# [CV 2/5] END learning_decay=0.9, n_components=10;, score=-231192.804 total time=  43.8s
# [CV 3/5] END learning_decay=0.9, n_components=10;, score=-227912.224 total time=  43.8s
# [CV 4/5] END learning_decay=0.9, n_components=10;, score=-234589.378 total time=  44.3s
# [CV 5/5] END learning_decay=0.9, n_components=10;, score=-229141.535 total time=  44.2s
# GridSearchCV(cv=5, estimator=LatentDirichletAllocation(n_jobs=-1),
#              param_grid={'learning_decay': [0.5, 0.6, 0.7, 0.8, 0.9],
#                          'n_components': [5, 6, 7, 8, 9, 10]},
#              verbose=3)

# %%
# Best Model
best_lda_model = model.best_estimator_

# Model Parameters
print("Best Model's Params: ", model.best_params_)

# Log Likelihood Score
print("Best Log Likelihood Score: ", model.best_score_)

# Perplexity
print("Model Perplexity: ", best_lda_model.perplexity(train_data))
# Out:
# Best Model's Params:  {'learning_decay': 0.9, 'n_components': 5}
# Best Log Likelihood Score:  -218536.96414427334
# Model Perplexity:  246.68303129872697

# %%
joblib.dump(model, 'grid_search_300.pkl')
# Out:
# ['grid_search_300.pkl']

# %%
# Get Log Likelyhoods from Grid Search Output
n_topics = [5,6,7,8,9,10]
log_likelyhoods_5 = [round(model.cv_results_['mean_test_score'][index]) for index, gscore in enumerate(model.cv_results_['params']) if gscore['learning_decay']==0.5]
log_likelyhoods_6 = [round(model.cv_results_['mean_test_score'][index]) for index, gscore in enumerate(model.cv_results_['params']) if gscore['learning_decay']==0.6]
log_likelyhoods_7 = [round(model.cv_results_['mean_test_score'][index]) for index, gscore in enumerate(model.cv_results_['params']) if gscore['learning_decay']==0.7]
log_likelyhoods_8 = [round(model.cv_results_['mean_test_score'][index]) for index, gscore in enumerate(model.cv_results_['params']) if gscore['learning_decay']==0.8]
log_likelyhoods_9 = [round(model.cv_results_['mean_test_score'][index]) for index, gscore in enumerate(model.cv_results_['params']) if gscore['learning_decay']==0.9]


# Show graph
plt.figure(figsize=(10, 10))
plt.plot(n_topics, log_likelyhoods_5, label='0.5')
plt.plot(n_topics, log_likelyhoods_6, label='0.6')
plt.plot(n_topics, log_likelyhoods_7, label='0.7')
plt.plot(n_topics, log_likelyhoods_8, label='0.8')
plt.plot(n_topics, log_likelyhoods_9, label='0.9')
plt.title("Choosing Optimal LDA Model")
plt.xlabel("Num Topics")
plt.ylabel("Log Likelyhood Scores")
plt.ticklabel_format(style='plain', useOffset=False, axis='y') 
plt.legend(title='Learning decay', loc='best')
plt.show()

# %%
# Create Document - Topic Matrix
lda_output = best_lda_model.transform(train_data)

# column names
topicnames = ["Topic" + str(i) for i in range(best_lda_model.n_components)]

# index names
docnames = ["Doc" + str(i) for i in range(len(extracted_data))]

# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(lda_output, 2), columns=topicnames, index=docnames)

# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic['dominant_topic'] = dominant_topic

# Styling
def color_green(val):
    color = 'green' if val > .1 else 'black'
    return 'color: {col}'.format(col=color)

def make_bold(val):
    weight = 700 if val > .1 else 400
    return 'font-weight: {weight}'.format(weight=weight)

# Apply Style
df_document_topics = df_document_topic.head(30).style.applymap(color_green).applymap(make_bold)
df_document_topics
# Out:
# <style type="text/css">
# #T_d9200_row0_col0, #T_d9200_row0_col1, #T_d9200_row0_col3, #T_d9200_row0_col4, #T_d9200_row1_col0, #T_d9200_row1_col3, #T_d9200_row2_col0, #T_d9200_row2_col1, #T_d9200_row2_col2, #T_d9200_row2_col4, #T_d9200_row3_col1, #T_d9200_row3_col2, #T_d9200_row3_col4, #T_d9200_row3_col5, #T_d9200_row4_col0, #T_d9200_row4_col1, #T_d9200_row4_col2, #T_d9200_row4_col4, #T_d9200_row5_col0, #T_d9200_row5_col2, #T_d9200_row5_col3, #T_d9200_row5_col4, #T_d9200_row6_col1, #T_d9200_row6_col2, #T_d9200_row6_col4, #T_d9200_row7_col1, #T_d9200_row7_col3, #T_d9200_row7_col4, #T_d9200_row7_col5, #T_d9200_row8_col1, #T_d9200_row8_col2, #T_d9200_row8_col3, #T_d9200_row8_col4, #T_d9200_row8_col5, #T_d9200_row9_col1, #T_d9200_row9_col3, #T_d9200_row9_col4, #T_d9200_row9_col5, #T_d9200_row10_col0, #T_d9200_row10_col1, #T_d9200_row10_col2, #T_d9200_row10_col3, #T_d9200_row11_col0, #T_d9200_row11_col1, #T_d9200_row11_col2, #T_d9200_row11_col3, #T_d9200_row12_col0, #T_d9200_row12_col1, #T_d9200_row12_col2, #T_d9200_row12_col4, #T_d9200_row13_col1, #T_d9200_row13_col2, #T_d9200_row13_col5, #T_d9200_row14_col1, #T_d9200_row14_col2, #T_d9200_row14_col3, #T_d9200_row14_col4, #T_d9200_row14_col5, #T_d9200_row15_col0, #T_d9200_row15_col1, #T_d9200_row15_col2, #T_d9200_row15_col4, #T_d9200_row16_col0, #T_d9200_row16_col1, #T_d9200_row16_col2, #T_d9200_row17_col1, #T_d9200_row17_col2, #T_d9200_row17_col3, #T_d9200_row17_col4, #T_d9200_row17_col5, #T_d9200_row18_col0, #T_d9200_row18_col1, #T_d9200_row18_col2, #T_d9200_row18_col4, #T_d9200_row19_col0, #T_d9200_row19_col1, #T_d9200_row19_col3, #T_d9200_row20_col1, #T_d9200_row20_col2, #T_d9200_row20_col3, #T_d9200_row20_col4, #T_d9200_row20_col5, #T_d9200_row21_col0, #T_d9200_row21_col1, #T_d9200_row22_col1, #T_d9200_row22_col2, #T_d9200_row22_col3, #T_d9200_row23_col1, #T_d9200_row24_col0, #T_d9200_row24_col1, #T_d9200_row24_col3, #T_d9200_row24_col4, #T_d9200_row25_col1, #T_d9200_row25_col2, #T_d9200_row25_col4, #T_d9200_row26_col0, #T_d9200_row26_col1, #T_d9200_row26_col2, #T_d9200_row26_col4, #T_d9200_row27_col1, #T_d9200_row27_col3, #T_d9200_row27_col4, #T_d9200_row27_col5, #T_d9200_row28_col0, #T_d9200_row28_col1, #T_d9200_row28_col3, #T_d9200_row28_col4, #T_d9200_row29_col1, #T_d9200_row29_col2, #T_d9200_row29_col3, #T_d9200_row29_col4, #T_d9200_row29_col5 {
#   color: black;
#   font-weight: 400;
# }
# #T_d9200_row0_col2, #T_d9200_row0_col5, #T_d9200_row1_col1, #T_d9200_row1_col2, #T_d9200_row1_col4, #T_d9200_row1_col5, #T_d9200_row2_col3, #T_d9200_row2_col5, #T_d9200_row3_col0, #T_d9200_row3_col3, #T_d9200_row4_col3, #T_d9200_row4_col5, #T_d9200_row5_col1, #T_d9200_row5_col5, #T_d9200_row6_col0, #T_d9200_row6_col3, #T_d9200_row6_col5, #T_d9200_row7_col0, #T_d9200_row7_col2, #T_d9200_row8_col0, #T_d9200_row9_col0, #T_d9200_row9_col2, #T_d9200_row10_col4, #T_d9200_row10_col5, #T_d9200_row11_col4, #T_d9200_row11_col5, #T_d9200_row12_col3, #T_d9200_row12_col5, #T_d9200_row13_col0, #T_d9200_row13_col3, #T_d9200_row13_col4, #T_d9200_row14_col0, #T_d9200_row15_col3, #T_d9200_row15_col5, #T_d9200_row16_col3, #T_d9200_row16_col4, #T_d9200_row16_col5, #T_d9200_row17_col0, #T_d9200_row18_col3, #T_d9200_row18_col5, #T_d9200_row19_col2, #T_d9200_row19_col4, #T_d9200_row19_col5, #T_d9200_row20_col0, #T_d9200_row21_col2, #T_d9200_row21_col3, #T_d9200_row21_col4, #T_d9200_row21_col5, #T_d9200_row22_col0, #T_d9200_row22_col4, #T_d9200_row22_col5, #T_d9200_row23_col0, #T_d9200_row23_col2, #T_d9200_row23_col3, #T_d9200_row23_col4, #T_d9200_row23_col5, #T_d9200_row24_col2, #T_d9200_row24_col5, #T_d9200_row25_col0, #T_d9200_row25_col3, #T_d9200_row25_col5, #T_d9200_row26_col3, #T_d9200_row26_col5, #T_d9200_row27_col0, #T_d9200_row27_col2, #T_d9200_row28_col2, #T_d9200_row28_col5, #T_d9200_row29_col0 {
#   color: green;
#   font-weight: 700;
# }
# </style>
# <table id="T_d9200">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9200_level0_col0" class="col_heading level0 col0" >Topic0</th>
#       <th id="T_d9200_level0_col1" class="col_heading level0 col1" >Topic1</th>
#       <th id="T_d9200_level0_col2" class="col_heading level0 col2" >Topic2</th>
#       <th id="T_d9200_level0_col3" class="col_heading level0 col3" >Topic3</th>
#       <th id="T_d9200_level0_col4" class="col_heading level0 col4" >Topic4</th>
#       <th id="T_d9200_level0_col5" class="col_heading level0 col5" >dominant_topic</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9200_level0_row0" class="row_heading level0 row0" >Doc0</th>
#       <td id="T_d9200_row0_col0" class="data row0 col0" >0.070000</td>
#       <td id="T_d9200_row0_col1" class="data row0 col1" >0.070000</td>
#       <td id="T_d9200_row0_col2" class="data row0 col2" >0.700000</td>
#       <td id="T_d9200_row0_col3" class="data row0 col3" >0.070000</td>
#       <td id="T_d9200_row0_col4" class="data row0 col4" >0.080000</td>
#       <td id="T_d9200_row0_col5" class="data row0 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d9200_level0_row1" class="row_heading level0 row1" >Doc1</th>
#       <td id="T_d9200_row1_col0" class="data row1 col0" >0.070000</td>
#       <td id="T_d9200_row1_col1" class="data row1 col1" >0.200000</td>
#       <td id="T_d9200_row1_col2" class="data row1 col2" >0.420000</td>
#       <td id="T_d9200_row1_col3" class="data row1 col3" >0.070000</td>
#       <td id="T_d9200_row1_col4" class="data row1 col4" >0.250000</td>
#       <td id="T_d9200_row1_col5" class="data row1 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d9200_level0_row2" class="row_heading level0 row2" >Doc2</th>
#       <td id="T_d9200_row2_col0" class="data row2 col0" >0.080000</td>
#       <td id="T_d9200_row2_col1" class="data row2 col1" >0.080000</td>
#       <td id="T_d9200_row2_col2" class="data row2 col2" >0.080000</td>
#       <td id="T_d9200_row2_col3" class="data row2 col3" >0.690000</td>
#       <td id="T_d9200_row2_col4" class="data row2 col4" >0.080000</td>
#       <td id="T_d9200_row2_col5" class="data row2 col5" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d9200_level0_row3" class="row_heading level0 row3" >Doc3</th>
#       <td id="T_d9200_row3_col0" class="data row3 col0" >0.490000</td>
#       <td id="T_d9200_row3_col1" class="data row3 col1" >0.070000</td>
#       <td id="T_d9200_row3_col2" class="data row3 col2" >0.070000</td>
#       <td id="T_d9200_row3_col3" class="data row3 col3" >0.300000</td>
#       <td id="T_d9200_row3_col4" class="data row3 col4" >0.070000</td>
#       <td id="T_d9200_row3_col5" class="data row3 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d9200_level0_row4" class="row_heading level0 row4" >Doc4</th>
#       <td id="T_d9200_row4_col0" class="data row4 col0" >0.060000</td>
#       <td id="T_d9200_row4_col1" class="data row4 col1" >0.060000</td>
#       <td id="T_d9200_row4_col2" class="data row4 col2" >0.060000</td>
#       <td id="T_d9200_row4_col3" class="data row4 col3" >0.770000</td>
#       <td id="T_d9200_row4_col4" class="data row4 col4" >0.060000</td>
#       <td id="T_d9200_row4_col5" class="data row4 col5" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d9200_level0_row5" class="row_heading level0 row5" >Doc5</th>
#       <td id="T_d9200_row5_col0" class="data row5 col0" >0.090000</td>
#       <td id="T_d9200_row5_col1" class="data row5 col1" >0.640000</td>
#       <td id="T_d9200_row5_col2" class="data row5 col2" >0.090000</td>
#       <td id="T_d9200_row5_col3" class="data row5 col3" >0.090000</td>
#       <td id="T_d9200_row5_col4" class="data row5 col4" >0.090000</td>
#       <td id="T_d9200_row5_col5" class="data row5 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d9200_level0_row6" class="row_heading level0 row6" >Doc6</th>
#       <td id="T_d9200_row6_col0" class="data row6 col0" >0.320000</td>
#       <td id="T_d9200_row6_col1" class="data row6 col1" >0.080000</td>
#       <td id="T_d9200_row6_col2" class="data row6 col2" >0.080000</td>
#       <td id="T_d9200_row6_col3" class="data row6 col3" >0.430000</td>
#       <td id="T_d9200_row6_col4" class="data row6 col4" >0.080000</td>
#       <td id="T_d9200_row6_c

# %%
df_topic_distribution = df_document_topic['dominant_topic'].value_counts().reset_index(name="Num Documents")
df_topic_distribution.columns = ['Topic Num', 'Num Documents']
df_topic_distribution
# Out:
#    Topic Num  Num Documents
# 0          0          31088
# 1          4          22810
# 2          3          16386
# 3          2          14506
# 4          1          13439

# %%
# Print the topics with their terms
terms = tfidf.get_feature_names_out()
lda_components = best_lda_model.components_

for index, component in enumerate(lda_components):
    zipped = zip(terms, component)
    top_terms_key=sorted(zipped, key = lambda t: t[1], reverse=True)[:10]
    top_terms_list=list(dict(top_terms_key).keys())
    print("Topic "+str(index)+": ",top_terms_list)
# Out:
# Topic 0:  ['safe', 'hurricaneharvey', 'prayers', 'stay', 'path', 'hurricane', 'harvey', 'praying', 'texas', 'affected']
# Topic 1:  ['help', 'harvey', 'hurricane', 'category', 'victims', 'landfall', 'breaking', 'texas', 'storm', 'winds']
# Topic 2:  ['hurricane', 'harvey', 'did', 'hurricaneharvey', 'time', 'houston', 'good', 'got', 'news', 'gulf']
# Topic 3:  ['hurricane', 'harvey', 'texas', 'pray', 'flooding', 'hurricaneharvey', 'hit', 'tx', 'need', 'rain']
# Topic 4:  ['hurricane', 'harvey', 'trump', 'disaster', 'im', 'texas', 'major', 'like', 'just', 'bad']

# %%
 cluster_no = best_lda_model.n_components

# Construct the k-means clusters
clusters = KMeans(n_clusters=cluster_no, random_state=100).fit_predict(lda_output)

# Build the Singular Value Decomposition(SVD) model
svd_model = TruncatedSVD(n_components=2)  # 2 components
lda_output_svd = svd_model.fit_transform(lda_output)

# X and Y axes of the plot using SVD decomposition
x = lda_output_svd[:, 0]
y = lda_output_svd[:, 1]

# Weights for the 15 columns of lda_output, for each component
print("Component's weights: \n", np.round(svd_model.components_, 2))

# Percentage of total information in 'lda_output' explained by the two components
print("Perc of Variance Explained: \n", np.round(svd_model.explained_variance_ratio_, 2))
# Out:
# Component's weights:
#  [[ 0.67  0.33  0.34  0.37  0.45]
#  [ 0.71 -0.17 -0.19 -0.2  -0.62]]
# Perc of Variance Explained:
#  [0.03 0.35]

# %%
# Plot
plt.figure(figsize=(14, 10))
plt.scatter(x, y, c=clusters)
plt.xlabel('Component 2')
plt.xlabel('Component 1')
plt.title("Segregation of Topic Clusters", )
plt.colorbar(ticks=[])

# %% [markdown]
# ## Auxiliary Testing

# %%
# # Define the number of topics or components
# num_components=10

# # Create LDA object
# model=LatentDirichletAllocation(n_components=num_components)

# # Fit and Transform SVD model on data
# lda_matrix = model.fit_transform(train_data)

# # Get Components 
# lda_components=model.components_

# %%
# Print the topics with their terms
# terms = tfidf.get_feature_names_out()

# for index, component in enumerate(lda_components):
#     zipped = zip(terms, component)
#     top_terms_key=sorted(zipped, key = lambda t: t[1], reverse=True)[:7]
#     top_terms_list=list(dict(top_terms_key).keys())
#     print("Topic "+str(index)+": ",top_terms_list)
