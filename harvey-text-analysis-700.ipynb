# %%
import pandas as pd
import numpy as np
import re
import joblib

from nltk.tokenize import RegexpTokenizer
from nltk import word_tokenize  
from nltk.stem import WordNetLemmatizer
import warnings

# Sklearn
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.cluster import KMeans

# Plotting tools
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# borrowed from stackoverflow https://stackoverflow.com/a/49146722
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r' ', string)

def remove_unwanted(document):

    # remove URLS 
    document = re.sub(r'http\S+', ' ', document)
    # remove emoji's
    document = remove_emoji(document)
    # remove punctuation
    document = re.sub("[^0-9A-Za-z ]", "" , document)
    # remove double spaces
    document = document.replace('  ',"")
    
    return document.strip()

# %%
# print(data[["Likes","Retweets"]].describe())
# extracted_data = data[(data["Likes"] >= 3) & (data["Retweets"] >= 2)]
# text_corpus = extracted_data["Tweet"]

# %%
data = pd.read_csv("/kaggle/input/harvey-stressor/Harvey_Tweets_with_emotion.csv")

exclusive_emotion = ["approval","desire","admiration","love","gratitude","excitement","optimism","joy","amusement","neutral"]
extracted_data = data.loc[~data["Emotion"].isin(exclusive_emotion)]
text_corpus = extracted_data["Tweet"]

# %%
new_corpus = []

for text in text_corpus:

    clean_text = remove_unwanted(str(text))
    clean_text = ' '.join( [w for w in clean_text.split() if len(w)>1] )
    new_corpus.append(clean_text)

new_corpus = np.array(new_corpus)

# %%
tokenizer = RegexpTokenizer(r'\w+')

tfidf = TfidfVectorizer(lowercase=True,
                        stop_words='english',
                        ngram_range = (1,1),
                        tokenizer = tokenizer.tokenize,
                        max_features=  700,
                        encoding='utf-8')

train_data = tfidf.fit_transform(new_corpus.astype('U'))

# %%
# Materialize the sparse data
data_dense = train_data.todense()

# Compute Sparsicity = Percentage of Non-Zero cells
print("Sparsicity: ", ((data_dense > 0).sum()/data_dense.size)*100, "%")
# Out:
# Sparsicity:  0.8364085089797456 %

# %% [markdown]
# ## SAMPLE LDA

# %%
warnings.filterwarnings('ignore')
lda_model = LatentDirichletAllocation(n_components=20,               # Number of topics
                                      max_iter=10,               # Max learning iterations  
                                      random_state=100,          # Random state
                                      evaluate_every = -1,       # compute perplexity every n iters, default: Don't
                                      n_jobs = -1,               # Use all available CPUs
                                     )
lda_output = lda_model.fit_transform(train_data)

print(lda_model)  # Model attributes
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# LatentDirichletAllocation(n_components=20, n_jobs=-1, random_state=100)

# %%
# Log Likelyhood: Higher the better
print("Log Likelihood: ", lda_model.score(train_data))

# Perplexity: Lower the better. Perplexity = exp(-1. * log-likelihood per word)
print("Perplexity: ", lda_model.perplexity(train_data))

# See model parameters
print(lda_model.get_params())
# Out:
# Log Likelihood:  -1431533.0674467925
# Perplexity:  900.8950452291238
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 20, 'n_jobs': -1, 'perp_tol': 0.1, 'random_state': 100, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}

# %% [markdown]
# ## GridSearch LDA

# %%
# Define Search Param
search_params = {'n_components': [5,6,7,8,9,10], 'learning_decay': [.5,.6,.7,.8,.9]}
# search_params = {'n_components': [10, 15], 'learning_decay': [.5, .7, .9]}

# Init the Model
lda = LatentDirichletAllocation(n_jobs=-1)

# Init Grid Search Class
model = GridSearchCV(lda, param_grid=search_params, verbose=3, cv=5)

# Do the Grid Search
model.fit(train_data)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5] END learning_decay=0.5, n_components=5;, score=-269876.904 total time=  41.2s
# [CV 2/5] END learning_decay=0.5, n_components=5;, score=-269860.250 total time=  41.6s
# [CV 3/5] END learning_decay=0.5, n_components=5;, score=-271057.891 total time=  40.9s
# [CV 4/5] END learning_decay=0.5, n_components=5;, score=-275295.910 total time=  42.6s
# [CV 5/5] END learning_decay=0.5, n_components=5;, score=-276384.570 total time=  42.0s
# [CV 1/5] END learning_decay=0.5, n_components=6;, score=-273724.814 total time=  39.8s
# [CV 2/5] END learning_decay=0.5, n_components=6;, score=-274877.095 total time=  39.8s
# [CV 3/5] END learning_decay=0.5, n_components=6;, score=-273526.507 total time=  39.0s
# [CV 4/5] END learning_decay=0.5, n_components=6;, score=-278801.488 total time=  40.4s
# [CV 5/5] END learning_decay=0.5, n_components=6;, score=-282548.759 total time=  40.8s
# [CV 1/5] END learning_decay=0.5, n_components=7;, score=-275800.670 total time=  38.5s
# [CV 2/5] END learning_decay=0.5, n_components=7;, score=-276265.503 total time=  38.7s
# [CV 3/5] END learning_decay=0.5, n_components=7;, score=-278764.731 total time=  38.7s
# [CV 4/5] END learning_decay=0.5, n_components=7;, score=-278011.937 total time=  38.4s
# [CV 5/5] END learning_decay=0.5, n_components=7;, score=-282957.558 total time=  38.3s
# [CV 1/5] END learning_decay=0.5, n_components=8;, score=-277370.533 total time=  37.0s
# [CV 2/5] END learning_decay=0.5, n_components=8;, score=-279160.942 total time=  37.4s
# [CV 3/5] END learning_decay=0.5, n_components=8;, score=-279071.730 total time=  37.6s
# [CV 4/5] END learning_decay=0.5, n_components=8;, score=-280295.300 total time=  37.6s
# [CV 5/5] END learning_decay=0.5, n_components=8;, score=-287351.705 total time=  38.0s
# [CV 1/5] END learning_decay=0.5, n_components=9;, score=-280540.304 total time=  37.0s
# [CV 2/5] END learning_decay=0.5, n_components=9;, score=-282880.050 total time=  37.1s
# [CV 3/5] END learning_decay=0.5, n_components=9;, score=-282660.087 total time=  36.1s
# [CV 4/5] END learning_decay=0.5, n_components=9;, score=-283021.008 total time=  37.1s
# [CV 5/5] END learning_decay=0.5, n_components=9;, score=-291780.322 total time=  37.3s
# [CV 1/5] END learning_decay=0.5, n_components=10;, score=-282702.897 total time=  35.6s
# [CV 2/5] END learning_decay=0.5, n_components=10;, score=-285638.801 total time=  36.2s
# [CV 3/5] END learning_decay=0.5, n_components=10;, score=-284043.230 total time=  36.4s
# [CV 4/5] END learning_decay=0.5, n_components=10;, score=-286500.328 total time=  36.3s
# [CV 5/5] END learning_decay=0.5, n_components=10;, score=-293195.698 total time=  36.2s
# [CV 1/5] END learning_decay=0.6, n_components=5;, score=-271524.854 total time=  41.9s
# [CV 2/5] END learning_decay=0.6, n_components=5;, score=-270723.537 total time=  41.6s
# [CV 3/5] END learning_decay=0.6, n_components=5;, score=-272358.228 total time=  42.3s
# [CV 4/5] END learning_decay=0.6, n_components=5;, score=-273002.739 total time=  41.8s
# [CV 5/5] END learning_decay=0.6, n_components=5;, score=-276437.922 total time=  41.2s
# [CV 1/5] END learning_decay=0.6, n_components=6;, score=-272747.842 total time=  39.0s
# [CV 2/5] END learning_decay=0.6, n_components=6;, score=-273631.822 total time=  39.1s
# [CV 3/5] END learning_decay=0.6, n_components=6;, score=-273929.919 total time=  38.6s
# [CV 4/5] END learning_decay=0.6, n_components=6;, score=-276896.944 total time=  40.2s
# [CV 5/5] END learning_decay=0.6, n_components=6;, score=-280658.707 total time=  39.3s
# [CV 1/5] END learning_decay=0.6, n_components=7;, score=-276938.157 total time=  38.3s
# [CV 2/5] END learning_decay=0.6, n_components=7;, score=-278179.309 total time=  38.6s
# [CV 3/5] END learning_decay=0.6, n_components=7;, score=-278412.491 total time=  38.8s
# [CV 4/5] END learning_decay=0.6, n_components=7;, score=-279805.055 total time=  38.7s
# [CV 5/5] END learning_decay=0.6, n_components=7;, score=-283598.806 total time=  38.9s
# [CV 1/5] END learning_decay=0.6, n_components=8;, score=-278689.313 total time=  36.6s
# [CV 2/5] END learning_decay=0.6, n_components=8;, score=-282278.063 total time=  37.7s
# [CV 3/5] END learning_decay=0.6, n_components=8;, score=-280552.969 total time=  37.6s
# [CV 4/5] END learning_decay=0.6, n_components=8;, score=-281148.851 total time=  37.3s
# [CV 5/5] END learning_decay=0.6, n_components=8;, score=-285924.882 total time=  37.1s
# [CV 1/5] END learning_decay=0.6, n_components=9;, score=-282510.749 total time=  36.8s
# [CV 2/5] END learning_decay=0.6, n_components=9;, score=-282686.263 total time=  36.4s
# [CV 3/5] END learning_decay=0.6, n_components=9;, score=-282343.694 total time=  36.5s
# [CV 4/5] END learning_decay=0.6, n_components=9;, score=-285394.272 total time=  37.5s
# [CV 5/5] END learning_decay=0.6, n_components=9;, score=-289097.127 total time=  37.1s
# [CV 1/5] END learning_decay=0.6, n_components=10;, score=-284716.640 total time=  36.2s
# [CV 2/5] END learning_decay=0.6, n_components=10;, score=-285532.076 total time=  36.3s
# [CV 3/5] END learning_decay=0.6, n_components=10;, score=-285775.404 total time=  36.3s
# [CV 4/5] END learning_decay=0.6, n_components=10;, score=-286299.624 total time=  36.6s
# [CV 5/5] END learning_decay=0.6, n_components=10;, score=-290091.327 total time=  36.6s
# [CV 1/5] END learning_decay=0.7, n_components=5;, score=-271295.720 total time=  41.4s
# [CV 2/5] END learning_decay=0.7, n_components=5;, score=-270352.995 total time=  41.4s
# [CV 3/5] END learning_decay=0.7, n_components=5;, score=-270764.916 total time=  41.4s
# [CV 4/5] END learning_decay=0.7, n_components=5;, score=-272650.006 total time=  42.1s
# [CV 5/5] END learning_decay=0.7, n_components=5;, score=-277435.222 total time=  42.4s
# [CV 1/5] END learning_decay=0.7, n_components=6;, score=-273749.653 total time=  39.8s
# [CV 2/5] END learning_decay=0.7, n_components=6;, score=-274722.425 total time=  39.5s
# [CV 3/5] END learning_decay=0.7, n_components=6;, score=-276132.756 total time=  39.7s
# [CV 4/5] END learning_decay=0.7, n_components=6;, score=-278141.050 total time=  39.9s
# [CV 5/5] END learning_decay=0.7, n_components=6;, score=-281156.092 total time=  39.5s
# [CV 1/5] END learning_decay=0.7, n_components=7;, score=-276919.148 total time=  38.6s
# [CV 2/5] END learning_decay=0.7, n_components=7;, score=-276628.590 total time=  38.1s
# [CV 3/5] END learning_decay=0.7, n_components=7;, score=-277917.206 total time=  38.1s
# [CV 4/5] END learning_decay=0.7, n_components=7;, score=-278490.822 total time=  38.6s
# [CV 5/5] END learning_decay=0.7, n_components=7;, score=-283565.027 total time=  39.1s
# [CV 1/5] END learning_decay=0.7, n_components=8;, score=-278258.339 total time=  37.1s
# [CV 2/5] END learning_decay=0.7, n_components=8;, score=-280616.803 total time=  36.9s
# [CV 3/5] END learning_decay=0.7, n_components=8;, score=-280795.648 total time=  37.1s
# [CV 4/5] END learning_decay=0.7, n_components=8;, score=-280854.126 total time=  36.6s
# [CV 5/5] END learning_decay=0.7, n_components=8;, score=-286040.092 total time=  37.3s
# [CV 1/5] END learning_decay=0.7, n_components=9;, score=-281275.040 total time=  36.5s
# [CV 2/5] END learning_decay=0.7, n_components=9;, score=-282999.600 total time=  36.6s
# [CV 3/5] END learning_decay=0.7, n_components=9;, score=-283303.893 total time=  36.5s
# [CV 4/5] END learning_decay=0.7, n_components=9;, score=-282684.065 total time=  36.9s
# [CV 5/5] END learning_decay=0.7, n_components=9;, score=-288421.919 total time=  36.7s
# [CV 1/5] END learning_decay=0.7, n_components=10;, score=-284132.844 total time=  36.2s
# [CV 2/5] END learning_decay=0.7, n_components=10;, score=-285147.055 total time=  36.0s
# [CV 3/5] END learning_decay=0.7, n_components=10;, score=-286105.698 total time=  36.4s
# [CV 4/5] END learning_decay=0.7, n_components=10;, score=-285414.418 total time=  35.6s
# [CV 5/5] END learning_decay=0.7, n_components=10;, score=-292387.405 total time=  37.7s
# [CV 1/5] END learning_decay=0.8, n_components=5;, score=-268985.180 total time=  41.2s
# [CV 2/5] END learning_decay=0.8, n_components=5;, score=-272352.947 total time=  42.7s
# [CV 3/5] END learning_decay=0.8, n_components=5;, score=-270384.101 total time=  40.3s
# [CV 4/5] END learning_decay=0.8, n_components=5;, score=-274268.074 total time=  42.1s
# [CV 5/5] END learning_decay=0.8, n_components=5;, score=-277179.612 total time=  40.8s
# [CV 1/5] END learning_decay=0.8, n_components=6;, score=-273515.905 total time=  39.4s
# [CV 2/5] END learning_decay=0.8, n_components=6;, score=-273806.322 total time=  39.2s
# [CV 3/5] END learning_decay=0.8, n_components=6;, score=-276322.386 total time=  40.5s
# [CV 4/5] END learning_decay=0.8, n_components=6;, score=-276117.815 total time=  39.3s
# [CV 5/5] END learning_decay=0.8, n_components=6;, score=-281268.964 total time=  40.1s
# [CV 1/5] END learning_decay=0.8, n_components=7;, score=-275896.826 total time=  38.0s
# [CV 2/5] END learning_decay=0.8, n_components=7;, score=-277455.633 total time=  38.0s
# [CV 3/5] END learning_decay=0.8, n_components=7;, score=-277619.626 total time=  39.0s
# [CV 4/5] END learning_decay=0.8, n_components=7;, score=-280001.402 total time=  38.8s
# [CV 5/5] END learning_decay=0.8, n_components=7;, score=-282356.306 total time=  38.7s
# [CV 1/5] END learning_decay=0.8, n_components=8;, score=-280342.935 total time=  37.2s
# [CV 2/5] END learning_decay=0.8, n_components=8;, score=-279619.744 total time=  36.9s
# [CV 3/5] END learning_decay=0.8, n_components=8;, score=-281075.225 total time=  37.6s
# [CV 4/5] END learning_decay=0.8, n_components=8;, score=-281150.622 total time=  36.7s
# [CV 5/5] END learning_decay=0.8, n_components=8;, score=-287370.443 total time=  37.4s
# [CV 1/5] END learning_decay=0.8, n_components=9;, score=-281032.622 total time=  35.7s
# [CV 2/5] END learning_decay=0.8, n_components=9;, score=-282246.282 total time=  36.3s
# [CV 3/5] END learning_decay=0.8, n_components=9;, score=-283681.565 total time=  36.9s
# [CV 4/5] END learning_decay=0.8, n_components=9;, score=-283480.012 total time=  36.9s
# [CV 5/5] END learning_decay=0.8, n_components=9;, score=-291069.416 total time=  37.4s
# [CV 1/5] END learning_decay=0.8, n_components=10;, score=-283511.992 total time=  36.1s
# [CV 2/5] END learning_decay=0.8, n_components=10;, score=-285656.817 total time=  35.6s
# [CV 3/5] END learning_decay=0.8, n_components=10;, score=-285156.916 total time=  35.3s
# [CV 4/5] END learning_decay=0.8, n_components=10;, score=-286823.588 total time=  36.3s
# [CV 5/5] END learning_decay=0.8, n_components=10;, score=-292441.104 total time=  36.6s
# [CV 1/5] END learning_decay=0.9, n_components=5;, score=-270424.679 total time=  41.5s
# [CV 2/5] END learning_decay=0.9, n_components=5;, score=-271206.658 total time=  41.4s
# [CV 3/5] END learning_decay=0.9, n_components=5;, score=-271176.580 total time=  41.4s
# [CV 4/5] END learning_decay=0.9, n_components=5;, score=-271776.149 total time=  41.1s
# [CV 5/5] END learning_decay=0.9, n_components=5;, score=-276689.955 total time=  42.4s
# [CV 1/5] END learning_decay=0.9, n_components=6;, score=-273686.177 total time=  39.4s
# [CV 2/5] END learning_decay=0.9, n_components=6;, score=-273497.082 total time=  39.0s
# [CV 3/5] END learning_decay=0.9, n_components=6;, score=-273996.301 total time=  39.5s
# [CV 4/5] END learning_decay=0.9, n_components=6;, score=-277558.320 total time=  40.0s
# [CV 5/5] END learning_decay=0.9, n_components=6;, score=-280183.474 total time=  40.1s
# [CV 1/5] END learning_decay=0.9, n_components=7;, score=-275269.610 total time=  38.7s
# [CV 2/5] END learning_decay=0.9, n_components=7;, score=-276939.081 total time=  38.3s
# [CV 3/5] END learning_decay=0.9, n_components=7;, score=-277182.639 total time=  37.8s
# [CV 4/5] END learning_decay=0.9, n_components=7;, score=-278358.156 total time=  37.6s
# [CV 5/5] END learning_decay=0.9, n_components=7;, score=-283951.460 total time=  38.1s
# [CV 1/5] END learning_decay=0.9, n_components=8;, score=-281181.617 total time=  37.8s
# [CV 2/5] END learning_decay=0.9, n_components=8;, score=-279633.790 total time=  37.2s
# [CV 3/5] END learning_decay=0.9, n_components=8;, score=-282013.213 total time=  37.7s
# [CV 4/5] END learning_decay=0.9, n_components=8;, score=-283287.855 total time=  38.0s
# [CV 5/5] END learning_decay=0.9, n_components=8;, score=-286470.057 total time=  37.7s
# [CV 1/5] END learning_decay=0.9, n_components=9;, score=-281992.637 total time=  36.9s
# [CV 2/5] END learning_decay=0.9, n_components=9;, score=-284577.552 total time=  37.2s
# [CV 3/5] END learning_decay=0.9, n_components=9;, score=-284643.460 total time=  37.0s
# [CV 4/5] END learning_decay=0.9, n_components=9;, score=-285404.895 total time=  37.3s
# [CV 5/5] END learning_decay=0.9, n_components=9;, score=-289462.734 total time=  36.8s
# [CV 1/5] END learning_decay=0.9, n_components=10;, score=-283357.976 total time=  36.3s
# [CV 2/5] END learning_decay=0.9, n_components=10;, score=-284859.934 total time=  35.9s
# [CV 3/5] END learning_decay=0.9, n_components=10;, score=-284000.274 total time=  36.1s
# [CV 4/5] END learning_decay=0.9, n_components=10;, score=-286106.395 total time=  35.9s
# [CV 5/5] END learning_decay=0.9, n_components=10;, score=-291472.407 total time=  36.5s
# GridSearchCV(cv=5, estimator=LatentDirichletAllocation(n_jobs=-1),
#              param_grid={'learning_decay': [0.5, 0.6, 0.7, 0.8, 0.9],
#                          'n_components': [5, 6, 7, 8, 9, 10]},
#              verbose=3)

# %%
# Best Model
best_lda_model = model.best_estimator_

# Model Parameters
print("Best Model's Params: ", model.best_params_)

# Log Likelihood Score
print("Best Log Likelihood Score: ", model.best_score_)

# Perplexity
print("Model Perplexity: ", best_lda_model.perplexity(train_data))
# Out:
# Best Model's Params:  {'learning_decay': 0.9, 'n_components': 5}
# Best Log Likelihood Score:  -272254.8042231236
# Model Perplexity:  522.4045148114088

# %%
joblib.dump(model, 'grid_search_300.pkl')
# Out:
# ['grid_search_300.pkl']

# %%
# Get Log Likelyhoods from Grid Search Output
n_topics = [5,6,7,8,9,10]
log_likelyhoods_5 = [round(model.cv_results_['mean_test_score'][index]) for index, gscore in enumerate(model.cv_results_['params']) if gscore['learning_decay']==0.5]
log_likelyhoods_6 = [round(model.cv_results_['mean_test_score'][index]) for index, gscore in enumerate(model.cv_results_['params']) if gscore['learning_decay']==0.6]
log_likelyhoods_7 = [round(model.cv_results_['mean_test_score'][index]) for index, gscore in enumerate(model.cv_results_['params']) if gscore['learning_decay']==0.7]
log_likelyhoods_8 = [round(model.cv_results_['mean_test_score'][index]) for index, gscore in enumerate(model.cv_results_['params']) if gscore['learning_decay']==0.8]
log_likelyhoods_9 = [round(model.cv_results_['mean_test_score'][index]) for index, gscore in enumerate(model.cv_results_['params']) if gscore['learning_decay']==0.9]


# Show graph
plt.figure(figsize=(10, 10))
plt.plot(n_topics, log_likelyhoods_5, label='0.5')
plt.plot(n_topics, log_likelyhoods_6, label='0.6')
plt.plot(n_topics, log_likelyhoods_7, label='0.7')
plt.plot(n_topics, log_likelyhoods_8, label='0.8')
plt.plot(n_topics, log_likelyhoods_9, label='0.9')
plt.title("Choosing Optimal LDA Model")
plt.xlabel("Num Topics")
plt.ylabel("Log Likelyhood Scores")
plt.ticklabel_format(style='plain', useOffset=False, axis='y') 
plt.legend(title='Learning decay', loc='best')
plt.show()

# %%
# Create Document - Topic Matrix
lda_output = best_lda_model.transform(train_data)

# column names
topicnames = ["Topic" + str(i) for i in range(best_lda_model.n_components)]

# index names
docnames = ["Doc" + str(i) for i in range(len(extracted_data))]

# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(lda_output, 2), columns=topicnames, index=docnames)

# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic['dominant_topic'] = dominant_topic

# Styling
def color_green(val):
    color = 'green' if val > .1 else 'black'
    return 'color: {col}'.format(col=color)

def make_bold(val):
    weight = 700 if val > .1 else 400
    return 'font-weight: {weight}'.format(weight=weight)

# Apply Style
df_document_topics = df_document_topic.head(30).style.applymap(color_green).applymap(make_bold)
df_document_topics
# Out:
# <style type="text/css">
# #T_9377d_row0_col0, #T_9377d_row0_col1, #T_9377d_row0_col2, #T_9377d_row0_col3, #T_9377d_row1_col1, #T_9377d_row1_col3, #T_9377d_row2_col0, #T_9377d_row2_col1, #T_9377d_row2_col2, #T_9377d_row2_col4, #T_9377d_row3_col0, #T_9377d_row3_col1, #T_9377d_row3_col2, #T_9377d_row3_col3, #T_9377d_row4_col0, #T_9377d_row4_col2, #T_9377d_row4_col4, #T_9377d_row5_col0, #T_9377d_row5_col1, #T_9377d_row5_col2, #T_9377d_row5_col4, #T_9377d_row6_col0, #T_9377d_row6_col3, #T_9377d_row6_col4, #T_9377d_row7_col0, #T_9377d_row7_col2, #T_9377d_row7_col3, #T_9377d_row8_col0, #T_9377d_row8_col1, #T_9377d_row8_col2, #T_9377d_row8_col3, #T_9377d_row9_col0, #T_9377d_row9_col2, #T_9377d_row10_col0, #T_9377d_row10_col1, #T_9377d_row10_col2, #T_9377d_row10_col4, #T_9377d_row11_col0, #T_9377d_row11_col2, #T_9377d_row11_col3, #T_9377d_row11_col4, #T_9377d_row12_col0, #T_9377d_row12_col1, #T_9377d_row12_col2, #T_9377d_row12_col4, #T_9377d_row13_col0, #T_9377d_row13_col2, #T_9377d_row13_col3, #T_9377d_row14_col0, #T_9377d_row14_col2, #T_9377d_row14_col3, #T_9377d_row14_col4, #T_9377d_row15_col0, #T_9377d_row15_col1, #T_9377d_row15_col2, #T_9377d_row15_col4, #T_9377d_row16_col0, #T_9377d_row16_col1, #T_9377d_row16_col3, #T_9377d_row16_col4, #T_9377d_row17_col0, #T_9377d_row17_col2, #T_9377d_row17_col3, #T_9377d_row17_col4, #T_9377d_row18_col0, #T_9377d_row18_col1, #T_9377d_row18_col3, #T_9377d_row18_col4, #T_9377d_row19_col0, #T_9377d_row19_col2, #T_9377d_row19_col4, #T_9377d_row20_col0, #T_9377d_row20_col2, #T_9377d_row21_col1, #T_9377d_row21_col3, #T_9377d_row22_col0, #T_9377d_row22_col1, #T_9377d_row22_col4, #T_9377d_row23_col2, #T_9377d_row23_col3, #T_9377d_row23_col4, #T_9377d_row23_col5, #T_9377d_row24_col0, #T_9377d_row24_col2, #T_9377d_row24_col3, #T_9377d_row24_col4, #T_9377d_row25_col0, #T_9377d_row25_col1, #T_9377d_row25_col2, #T_9377d_row26_col0, #T_9377d_row26_col2, #T_9377d_row26_col3, #T_9377d_row26_col4, #T_9377d_row27_col1, #T_9377d_row27_col2, #T_9377d_row28_col0, #T_9377d_row28_col1, #T_9377d_row28_col4, #T_9377d_row29_col0, #T_9377d_row29_col2, #T_9377d_row29_col3, #T_9377d_row29_col4 {
#   color: black;
#   font-weight: 400;
# }
# #T_9377d_row0_col4, #T_9377d_row0_col5, #T_9377d_row1_col0, #T_9377d_row1_col2, #T_9377d_row1_col4, #T_9377d_row1_col5, #T_9377d_row2_col3, #T_9377d_row2_col5, #T_9377d_row3_col4, #T_9377d_row3_col5, #T_9377d_row4_col1, #T_9377d_row4_col3, #T_9377d_row4_col5, #T_9377d_row5_col3, #T_9377d_row5_col5, #T_9377d_row6_col1, #T_9377d_row6_col2, #T_9377d_row6_col5, #T_9377d_row7_col1, #T_9377d_row7_col4, #T_9377d_row7_col5, #T_9377d_row8_col4, #T_9377d_row8_col5, #T_9377d_row9_col1, #T_9377d_row9_col3, #T_9377d_row9_col4, #T_9377d_row9_col5, #T_9377d_row10_col3, #T_9377d_row10_col5, #T_9377d_row11_col1, #T_9377d_row11_col5, #T_9377d_row12_col3, #T_9377d_row12_col5, #T_9377d_row13_col1, #T_9377d_row13_col4, #T_9377d_row13_col5, #T_9377d_row14_col1, #T_9377d_row14_col5, #T_9377d_row15_col3, #T_9377d_row15_col5, #T_9377d_row16_col2, #T_9377d_row16_col5, #T_9377d_row17_col1, #T_9377d_row17_col5, #T_9377d_row18_col2, #T_9377d_row18_col5, #T_9377d_row19_col1, #T_9377d_row19_col3, #T_9377d_row19_col5, #T_9377d_row20_col1, #T_9377d_row20_col3, #T_9377d_row20_col4, #T_9377d_row20_col5, #T_9377d_row21_col0, #T_9377d_row21_col2, #T_9377d_row21_col4, #T_9377d_row21_col5, #T_9377d_row22_col2, #T_9377d_row22_col3, #T_9377d_row22_col5, #T_9377d_row23_col0, #T_9377d_row23_col1, #T_9377d_row24_col1, #T_9377d_row24_col5, #T_9377d_row25_col3, #T_9377d_row25_col4, #T_9377d_row25_col5, #T_9377d_row26_col1, #T_9377d_row26_col5, #T_9377d_row27_col0, #T_9377d_row27_col3, #T_9377d_row27_col4, #T_9377d_row27_col5, #T_9377d_row28_col2, #T_9377d_row28_col3, #T_9377d_row28_col5, #T_9377d_row29_col1, #T_9377d_row29_col5 {
#   color: green;
#   font-weight: 700;
# }
# </style>
# <table id="T_9377d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9377d_level0_col0" class="col_heading level0 col0" >Topic0</th>
#       <th id="T_9377d_level0_col1" class="col_heading level0 col1" >Topic1</th>
#       <th id="T_9377d_level0_col2" class="col_heading level0 col2" >Topic2</th>
#       <th id="T_9377d_level0_col3" class="col_heading level0 col3" >Topic3</th>
#       <th id="T_9377d_level0_col4" class="col_heading level0 col4" >Topic4</th>
#       <th id="T_9377d_level0_col5" class="col_heading level0 col5" >dominant_topic</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9377d_level0_row0" class="row_heading level0 row0" >Doc0</th>
#       <td id="T_9377d_row0_col0" class="data row0 col0" >0.070000</td>
#       <td id="T_9377d_row0_col1" class="data row0 col1" >0.070000</td>
#       <td id="T_9377d_row0_col2" class="data row0 col2" >0.090000</td>
#       <td id="T_9377d_row0_col3" class="data row0 col3" >0.070000</td>
#       <td id="T_9377d_row0_col4" class="data row0 col4" >0.710000</td>
#       <td id="T_9377d_row0_col5" class="data row0 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_9377d_level0_row1" class="row_heading level0 row1" >Doc1</th>
#       <td id="T_9377d_row1_col0" class="data row1 col0" >0.210000</td>
#       <td id="T_9377d_row1_col1" class="data row1 col1" >0.060000</td>
#       <td id="T_9377d_row1_col2" class="data row1 col2" >0.250000</td>
#       <td id="T_9377d_row1_col3" class="data row1 col3" >0.060000</td>
#       <td id="T_9377d_row1_col4" class="data row1 col4" >0.420000</td>
#       <td id="T_9377d_row1_col5" class="data row1 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_9377d_level0_row2" class="row_heading level0 row2" >Doc2</th>
#       <td id="T_9377d_row2_col0" class="data row2 col0" >0.070000</td>
#       <td id="T_9377d_row2_col1" class="data row2 col1" >0.070000</td>
#       <td id="T_9377d_row2_col2" class="data row2 col2" >0.070000</td>
#       <td id="T_9377d_row2_col3" class="data row2 col3" >0.720000</td>
#       <td id="T_9377d_row2_col4" class="data row2 col4" >0.070000</td>
#       <td id="T_9377d_row2_col5" class="data row2 col5" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9377d_level0_row3" class="row_heading level0 row3" >Doc3</th>
#       <td id="T_9377d_row3_col0" class="data row3 col0" >0.070000</td>
#       <td id="T_9377d_row3_col1" class="data row3 col1" >0.070000</td>
#       <td id="T_9377d_row3_col2" class="data row3 col2" >0.070000</td>
#       <td id="T_9377d_row3_col3" class="data row3 col3" >0.070000</td>
#       <td id="T_9377d_row3_col4" class="data row3 col4" >0.720000</td>
#       <td id="T_9377d_row3_col5" class="data row3 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_9377d_level0_row4" class="row_heading level0 row4" >Doc4</th>
#       <td id="T_9377d_row4_col0" class="data row4 col0" >0.060000</td>
#       <td id="T_9377d_row4_col1" class="data row4 col1" >0.350000</td>
#       <td id="T_9377d_row4_col2" class="data row4 col2" >0.060000</td>
#       <td id="T_9377d_row4_col3" class="data row4 col3" >0.480000</td>
#       <td id="T_9377d_row4_col4" class="data row4 col4" >0.060000</td>
#       <td id="T_9377d_row4_col5" class="data row4 col5" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9377d_level0_row5" class="row_heading level0 row5" >Doc5</th>
#       <td id="T_9377d_row5_col0" class="data row5 col0" >0.080000</td>
#       <td id="T_9377d_row5_col1" class="data row5 col1" >0.070000</td>
#       <td id="T_9377d_row5_col2" class="data row5 col2" >0.070000</td>
#       <td id="T_9377d_row5_col3" class="data row5 col3" >0.710000</td>
#       <td id="T_9377d_row5_col4" class="data row5 col4" >0.070000</td>
#       <td id="T_9377d_row5_col5" class="data row5 col5" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9377d_level0_row6" class="row_heading level0 row6" >Doc6</th>
#       <td id="T_9377d_row6_col0" class="data row6 col0" >0.080000</td>
#       <td id="T_9377d_row6_col1" class="data row6 col1" >0.310000</td>
#       <td id="T_9377d_row6_col2" class="data row6 col2" >0.440000</td>
#       <td id="T_9377d_row6_col3" class="data row6 col3" >0.080000</td>
#       <td id="T_9377d_row6_col4" class="data row6 col4" >0.080000</td>
#       <td id="T_9377d_row6_c

# %%
df_topic_distribution = df_document_topic['dominant_topic'].value_counts().reset_index(name="Num Documents")
df_topic_distribution.columns = ['Topic Num', 'Num Documents']
df_topic_distribution
# Out:
#    Topic Num  Num Documents
# 0          1          27924
# 1          2          22308
# 2          3          19007
# 3          4          18808
# 4          0          10182

# %%
# Print the topics with their terms
terms = tfidf.get_feature_names_out()
lda_components = best_lda_model.components_

for index, component in enumerate(lda_components):
    zipped = zip(terms, component)
    top_terms_key=sorted(zipped, key = lambda t: t[1], reverse=True)[:10]
    top_terms_list=list(dict(top_terms_key).keys())
    print("Topic "+str(index)+": ",top_terms_list)
# Out:
# Topic 0:  ['hurricane', 'harvey', 'disaster', 'major', 'houston', 'texas', 'trump', 'governor', 'flood', 'climate']
# Topic 1:  ['hurricane', 'harvey', 'safe', 'prayers', 'stay', 'hurricaneharvey', 'path', 'texas', 'affected', 'praying']
# Topic 2:  ['harvey', 'hurricane', 'hurricaneharvey', 'im', 'landfall', 'texas', 'bad', 'corpus', 'storm', 'makes']
# Topic 3:  ['hurricane', 'harvey', 'help', 'victims', 'category', 'storm', 'texas', 'trump', 'heres', 'catastrophic']
# Topic 4:  ['hurricane', 'harvey', 'hurricaneharvey', 'god', 'safe', 'texas', 'dont', 'fuck', 'yall', 'shit']

# %%
 cluster_no = best_lda_model.n_components

# Construct the k-means clusters
clusters = KMeans(n_clusters=cluster_no, random_state=100).fit_predict(lda_output)

# Build the Singular Value Decomposition(SVD) model
svd_model = TruncatedSVD(n_components=2)  # 2 components
lda_output_svd = svd_model.fit_transform(lda_output)

# X and Y axes of the plot using SVD decomposition
x = lda_output_svd[:, 0]
y = lda_output_svd[:, 1]

# Weights for the 15 columns of lda_output, for each component
print("Component's weights: \n", np.round(svd_model.components_, 2))

# Percentage of total information in 'lda_output' explained by the two components
print("Perc of Variance Explained: \n", np.round(svd_model.explained_variance_ratio_, 2))
# Out:
# Component's weights:
#  [[ 0.28  0.6   0.47  0.41  0.41]
#  [-0.09  0.78 -0.47 -0.31 -0.24]]
# Perc of Variance Explained:
#  [0.01 0.33]

# %%
# Plot
plt.figure(figsize=(14, 10))
plt.scatter(x, y, c=clusters)
plt.xlabel('Component 2')
plt.xlabel('Component 1')
plt.title("Segregation of Topic Clusters", )
plt.colorbar(ticks=[])

# %% [markdown]
# ## Auxiliary Testing

# %%
# # Define the number of topics or components
# num_components=10

# # Create LDA object
# model=LatentDirichletAllocation(n_components=num_components)

# # Fit and Transform SVD model on data
# lda_matrix = model.fit_transform(train_data)

# # Get Components 
# lda_components=model.components_

# %%
# Print the topics with their terms
# terms = tfidf.get_feature_names_out()

# for index, component in enumerate(lda_components):
#     zipped = zip(terms, component)
#     top_terms_key=sorted(zipped, key = lambda t: t[1], reverse=True)[:7]
#     top_terms_list=list(dict(top_terms_key).keys())
#     print("Topic "+str(index)+": ",top_terms_list)
